# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('hypertension_dataset.csv')

# %%
data
# Out:
#       Age  Salt_Intake  Stress_Score       BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           Normal             6.4  25.8
# 1      32         11.7            10           Normal             5.4  23.4
# 2      78          9.5             3           Normal             7.1  18.7
# 3      38         10.0            10     Hypertension             4.2  22.1
# 4      41          9.8             1  Prehypertension             5.8  16.2
# ...   ...          ...           ...              ...             ...   ...
# 1980   56         10.2             0           Normal             6.5  25.0
# 1981   29          8.9             4     Hypertension             6.9  16.9
# 1982   64          5.9             9           Normal             5.6  18.9
# 1983   35          7.4             8  Prehypertension             8.2  29.2
# 1984   38          7.3             0           Normal             8.3  18.6
#
# ...

# %%
data.isna().sum()
# Out:
# Age                   0
# Salt_Intake           0
# Stress_Score          0
# BP_History            0
# Sleep_Duration        0
# BMI                   0
# Medication          799
# Family_History        0
# Exercise_Level        0
# Smoking_Status        0
# Has_Hypertension      0
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#       Age  Salt_Intake  Stress_Score       BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           Normal             6.4  25.8
# 1      32         11.7            10           Normal             5.4  23.4
# 2      78          9.5             3           Normal             7.1  18.7
# 7      70          5.9             1     Hypertension             7.2  25.8
# 9      47          7.2             5           Normal             6.2  24.3
# ...   ...          ...           ...              ...             ...   ...
# 1975   49          7.7             0           Normal             7.5  17.2
# 1978   38          7.4             9  Prehypertension             6.2  23.6
# 1981   29          8.9             4     Hypertension             6.9  16.9
# 1983   35          7.4             8  Prehypertension             8.2  29.2
# 1984   38          7.3             0           Normal             8.3  18.6
#
# ...

# %%
data.describe()
# Out:
#                Age  Salt_Intake  Stress_Score  Sleep_Duration          BMI
# count  1985.000000  1985.000000   1985.000000     1985.000000  1985.000000
# mean     50.341058     8.531688      4.979345        6.452242    26.015315
# std      19.442042     1.994907      3.142303        1.542207     4.512857
# min      18.000000     2.500000      0.000000        1.500000    11.900000
# 25%      34.000000     7.200000      2.000000        5.400000    23.000000
# 50%      50.000000     8.500000      5.000000        6.500000    25.900000
# 75%      67.000000     9.900000      8.000000        7.500000    29.100000
# max      84.000000    16.400000     10.000000       11.400000    41.900000

# %%
data['Medication'].value_counts()
# Out:
# Medication
# Beta Blocker     412
# ACE Inhibitor    323
# Diuretic         245
# Other            206
# Name: count, dtype: int64

# %%
data['Medication'].fillna('None',inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3948\2620207471.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Medication'].fillna('None',inplace=True)

# %%
data
# Out:
#       Age  Salt_Intake  Stress_Score       BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           Normal             6.4  25.8
# 1      32         11.7            10           Normal             5.4  23.4
# 2      78          9.5             3           Normal             7.1  18.7
# 3      38         10.0            10     Hypertension             4.2  22.1
# 4      41          9.8             1  Prehypertension             5.8  16.2
# ...   ...          ...           ...              ...             ...   ...
# 1980   56         10.2             0           Normal             6.5  25.0
# 1981   29          8.9             4     Hypertension             6.9  16.9
# 1982   64          5.9             9           Normal             5.6  18.9
# 1983   35          7.4             8  Prehypertension             8.2  29.2
# 1984   38          7.3             0           Normal             8.3  18.6
#
# ...

# %%
data['Medication'].value_counts()
# Out:
# Medication
# None             799
# Beta Blocker     412
# ACE Inhibitor    323
# Diuretic         245
# Other            206
# Name: count, dtype: int64

# %%
data['BP_History'].value_counts()
# Out:
# BP_History
# Normal             796
# Prehypertension    620
# Hypertension       569
# Name: count, dtype: int64

# %%
data['BP_History'].shape
# Out:
# (1985,)

# %%
data.isna().sum()
# Out:
# Age                 0
# Salt_Intake         0
# Stress_Score        0
# BP_History          0
# Sleep_Duration      0
# BMI                 0
# Medication          0
# Family_History      0
# Exercise_Level      0
# Smoking_Status      0
# Has_Hypertension    0
# dtype: int64

# %%
data['BP_History'] = data['BP_History'].replace({'Normal' : 0, 'Prehypertension' : 1, 'Hypertension' : 2})
data['BP_History'].value_counts()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3948\1194353748.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['BP_History'] = data['BP_History'].replace({'Normal' : 0, 'Prehypertension' : 1, 'Hypertension' : 2})
# BP_History
# 0    796
# 1    620
# 2    569
# Name: count, dtype: int64

# %%
data['Medication'].value_counts()
# Out:
# Medication
# None             799
# Beta Blocker     412
# ACE Inhibitor    323
# Diuretic         245
# Other            206
# Name: count, dtype: int64

# %%
data['Medication'] = data['Medication'].replace({'None' : 0, 'Beta Blocker' : 1, 'ACE Inhibitor' : 2, 'Diuretic' : 3, 'Other' : 4})
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3948\2936746454.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Medication'] = data['Medication'].replace({'None' : 0, 'Beta Blocker' : 1, 'ACE Inhibitor' : 2, 'Diuretic' : 3, 'Other' : 4})

# %%
data
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           2             4.2  22.1
# 4      41          9.8             1           1             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           2             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           1             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication Family_History Exercise_Level Smoking_Status Has_Hypertension
# ...

# %%
data['Family_History'].value_counts()
# Out:
# Family_History
# No     1000
# Yes     985
# Name: count, dtype: int64

# %% [markdown]
# FAMILY HISTORY : TES = 0,NO =1

# %%
data['Family_History'] = data['Family_History'].replace({'Yes' : 0, 'No' : 1})
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3948\1052651149.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Family_History'] = data['Family_History'].replace({'Yes' : 0, 'No' : 1})

# %%
data
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           2             4.2  22.1
# 4      41          9.8             1           1             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           2             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           1             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History Exercise_Level Smoking_Status  \
# ...

# %%
data['Exercise_Level'].value_counts()
# Out:
# Exercise_Level
# Low         936
# Moderate    658
# High        391
# Name: count, dtype: int64

# %%
data['Exercise_Level'] = data['Exercise_Level'].replace({'Low' : 0, 'Moderate' : 1, 'High' : 2})
data
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           2             4.2  22.1
# 4      41          9.8             1           1             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           2             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           1             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History  Exercise_Level  Smoking_Status  \
# ...

# %%
data['Smoking_Status'].value_counts()
# Out:
# Smoking_Status
# 0    1417
# 1     568
# Name: count, dtype: int64

# %%
data['Smoking_Status'] = data['Smoking_Status'].replace({'Non-Smoker' : 0, 'Smoker' : 1})
data
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           2             4.2  22.1
# 4      41          9.8             1           1             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           2             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           1             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History  Exercise_Level  Smoking_Status  \
# ...

# %%
data['Has_Hypertension'].value_counts()
# Out:
# Has_Hypertension
# 0    1032
# 1     953
# Name: count, dtype: int64

# %%
data['Has_Hypertension'] = data['Has_Hypertension'].replace({'Yes' : 0, 'No': 1})

# %%
data
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 0      69          8.0             9           0             6.4  25.8
# 1      32         11.7            10           0             5.4  23.4
# 2      78          9.5             3           0             7.1  18.7
# 3      38         10.0            10           2             4.2  22.1
# 4      41          9.8             1           1             5.8  16.2
# ...   ...          ...           ...         ...             ...   ...
# 1980   56         10.2             0           0             6.5  25.0
# 1981   29          8.9             4           2             6.9  16.9
# 1982   64          5.9             9           0             5.6  18.9
# 1983   35          7.4             8           1             8.2  29.2
# 1984   38          7.3             0           0             8.3  18.6
#
#       Medication  Family_History  Exercise_Level  Smoking_Status  \
# ...

# %%
correlation_matrix = data.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data = correlation_matrix,annot = True)
# Out:
# <Axes: >

# %%
sns.countplot(data = data, x = 'Has_Hypertension',hue = 'Has_Hypertension')
# Out:
# <Axes: xlabel='Has_Hypertension', ylabel='count'>

# %%
X = data.drop('Has_Hypertension',axis=1)
y = data['Has_Hypertension']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=100)

# %%
y_train
# Out:
# 301     0
# 420     0
# 1121    1
# 876     1
# 545     1
#        ..
# 1879    1
# 1895    1
# 1859    0
# 792     1
# 1544    0
# Name: Has_Hypertension, Length: 1389, dtype: int64

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
prediction = model.predict(X_test)

# %%
classification_report = classification_report(y_test,prediction)
accuracy_score = accuracy_score(y_test,prediction)

# %%
print('Accuracy Score :',accuracy_score)
print('\nClassification Report :\n',classification_report)
# Out:
# Accuracy Score : 0.9748322147651006
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       301
#            1       0.97      0.98      0.97       295
#
#     accuracy                           0.97       596
#    macro avg       0.97      0.97      0.97       596
# weighted avg       0.97      0.97      0.97       596

# %%
X_test
# Out:
#       Age  Salt_Intake  Stress_Score  BP_History  Sleep_Duration   BMI  \
# 1537   62         12.5             2           2             6.2  29.9
# 426    29         10.1             5           2             6.5  23.9
# 719    83          7.3            10           1             9.1  23.9
# 341    18          8.4             9           0             6.3  28.2
# 264    35          9.2             5           1             7.2  25.2
# ...   ...          ...           ...         ...             ...   ...
# 1055   56          7.1             2           1             3.1  30.8
# 1976   68         12.5             9           2             6.3  26.7
# 1157   73          8.6             3           1             6.6  23.4
# 1168   71          7.3             9           2             7.5  26.7
# 78     28          8.3             8           2             5.9  26.0
#
#       Medication  Family_History  Exercise_Level  Smoking_Status
# ...

# %%
age = int(input('How old are you ? :\n'))
s_i = float(input('How much salt do you eat a day[in grams] ? :\n'))
stress_level = int(input('What is your Stress Level [from 1-10] ? :\n'))
Bp_h = int(input('Do you have any history of High Blood Pressure ? [NORMAL = 0, PREHYPERTENSION =1, HYPERTENSION =2] :\n'))
sleep = float(input('How many hours do you sleep ? :\n'))
bmi = float(input('What is your BMI [BODY MASS INDEX] ? :\n'))
medications = int(input('If you have any Medication ? [NONE : 0, BETA BLOCKER : 1, ACE INHIBITOR : 2, DIURATIC : 3, OTHER : 4] :\n'))
family_history = int(input('Family History of Hypertensions [Yes=0/No=1] :\n'))
excercise_level = int(input('Physical activity level: [Low = 0, Moderate = 1, High =2] :\n'))
smoking = int(input('Do you smoke ? [Yes = 1/ No = 0]:\n'))

new_test = [[age,s_i,stress_level,Bp_h,sleep,bmi,medications,family_history,excercise_level,smoking]]
# Out:
# How old are you ? :
#  22
# How much salt do you eat a day[in grams] ? :
#  12.5
# What is your Stress Level [from 1-10] ? :
#  7
# Do you have any history of High Blood Pressure ? [NORMAL = 0, PREHYPERTENSION =1, HYPERTENSION =2] :
#  0
# How many hours do you sleep ? :
#  7
# What is your BMI [BODY MASS INDEX] ? :
#  20.4
# If you have any Medication ? [NONE : 0, BETA BLOCKER : 1, ACE INHIBITOR : 2, DIURATIC : 3, OTHER : 4] :
#  0
# Family History of Hypertensions [Yes=0/No=1] :
#  1
# Physical activity level: [Low = 0, Moderate = 1, High =2] :
#  0
# Do you smoke ? [Yes = 1/ No = 0]:
#  0
# C:\Users\PC\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
new_predictions = model.predict(new_test)
print("RESULT:")
if new_predictions[0] == 1:
    print("---------------> You don't have Hypertension")
else:
    print('You have Hypertension.')
# Out:
# RESULT:
# ---------------> You don't have Hypertension
# C:\Users\PC\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
